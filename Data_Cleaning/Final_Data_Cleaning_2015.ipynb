# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook

# %%
finalCityDf=pd.DataFrame([])
cityList=['Bernalillo_County','Clark_County','Cook_County','Dallas_County','Davidson_County','Denver_County','Fulton_County','Hennepin_County','Jackson_County','King_County','Los_Angeles_County','Maricopa_County','Marion_County','Mecklenburg_County','Miami_Dade_County','New_York_County','Philadelphia_County','San_Francisco_County','Suffolk_County','Wayne_County']

#

# %%
for city in cityList:    
    #Import CSV file
    csvCity=f"{city}.csv"
    cityDf=pd.read_csv(csvCity)

    #Selected columns we want in our dataframe

    newColumns=['DATE', 'HourlyDryBulbTemperature']

    #Create new data frame based on given columns list

    shortCityDf=cityDf[newColumns]

    #Drop rows with null values. We do not fill values with zeros here as they might be mistaken for temperatures in further analysis

    shortCityDf=shortCityDf.dropna(axis=0)

    #Get only those rows from the month of January, create new data frame for just January

    CityDf2015=shortCityDf.loc[shortCityDf['DATE'].str.contains('2015-01'), newColumns]
    
    #Reset index for later reference in code
    CityDf2015=CityDf2015.reset_index(drop='False')

    #Convert temperatures into floats. Non-numerical values will be converted to NaN using 'coerce'
    CityDf2015['HourlyDryBulbTemperature']=pd.to_numeric(CityDf2015['HourlyDryBulbTemperature'], errors='coerce')
    
    #Drop the na values
    
    CityDf2015=CityDf2015.dropna(axis=0)

    #Get median temperature of the month

    monthlyMedian=CityDf2015['HourlyDryBulbTemperature'].median()

    #Calculate the months minimum temperature

    monthlyMin=CityDf2015['HourlyDryBulbTemperature'].min()

    #Calculate the months maximum temperature

    monthlyMax=CityDf2015['HourlyDryBulbTemperature'].max()

    #Get mean temperature and round to one decimal place

    monthlyMean=round((CityDf2015['HourlyDryBulbTemperature'].mean()),1)

    #Get county name from csv title

    countyName=csvCity.replace('.csv', '')

    #Split date based on '-'. Get year from list of split values. 

    year=(CityDf2015['DATE'].str.split(pat='-', n=0))[0][0]

    #Create a data frame by defining column names and passing in variables calculated from original dataframe

    CityDf2015Summary=[{'County':countyName,'Year':year, 'Jan_Min_Temp':monthlyMin, 'Jan_Max_Temp':monthlyMax, 'Jan_Mean_Temp':monthlyMean, 'Jan_Median_Temp':monthlyMedian}]
    CityDf2015SummaryDf=pd.DataFrame(CityDf2015Summary)

    #Set county name as the index

    CityDf2015SummaryDf=CityDf2015SummaryDf.set_index('County')
    
    finalCityDf=finalCityDf.append(CityDf2015SummaryDf)
finalCityDf
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (42,43,56) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (3,28,29,30,32,35,36,43,49,53,56,58,59,63,71,95,114,117,119) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (41,42,43,51,55,56) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (41,42,43,49,51) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (41,42,43,49,52,73) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (3,19,25,26,27,28,29,30,31,33,41,42,48,49,51,52,53,55,56,58,59,71,72,73,75,76,89,95,96,97,98,99,100,101,102,103,104,105,106,107,110) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (19,25,26,27,28,29,34,35,36,58,59,61,114,117,119) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (3,19,25,26,27,28,30,31,41,42,43,49,51,52,58,59,60,69,71,72,88,95,96,97,98,99,100,101,102,103,104,105,106,107,114,117,119) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (3,19,25,26,27,28,35,42,43,56,59,95,114,117,119) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (42,43,48,53,58,60,63) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (3,28,29,30,32,35,36,43,49,53,56,58,59,63,71,95,114,117,119) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (41,56) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (3,19,25,26,27,28,29,35,36,41,42,43,49,51,55,56,58,59,60,63,95,114,117,119) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (19,25,26,27,29,33,34,41,42,43,49,51,56,69,71,73,75,76,88,89) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (42,43) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (33,41,42,49,51,89) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (3,19,25,26,27,28,29,41,51,56,58,59,60,77,82,95,114,117,118,119) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (42,43) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (75,89) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                       Year  Jan_Min_Temp  Jan_Max_Temp  Jan_Mean_Temp  \
# County
# Bernalillo_County     2015          14.0          59.0           31.4
# Clark_County          2015          43.0          75.0           57.5
# Cook_County           2015          -8.0          43.0           23.3
# Dallas_County         2015          17.0          79.0           43.5
# Davidson_County       2015           4.0          67.0           38.4
# Denver_County         2015          -9.0          72.0           32.1
# Fulton_County         2015          10.0          66.0           42.1
# Hennepin_County       2015         -11.0          45.0           20.2
# Jackson_County        2015           0.0          73.0           32.3
# King_County           2015          25.0          63.0           44.2
# Los_Angeles_County    2015          43.0          75.0           57.5
# Maricopa_County       2015          27.0          77.0           53.8
# Marion_County         2015          -7.0          52.0           26.5
# Mecklenburg_County    2015          10.0          67.0           41.1
# Miami_Dade_County     2015          50.0          83.0           69.6
# New_York_County       2015           8.0          56.0           30.8
# Philadelphia_County   2015           9.0          59.0           31.8
# San_Francisco_County  2015          47.0          63.0           55.6
# Suffolk_County        2015          -1.0          52.0           26.5
# Wayne_County          2015          -2.0          42.0           21.9
#
#                       Jan_Median_Temp
# County
# Bernalillo_County                31.0
# Clark_County                     56.0
# Cook_County                      27.0
# Dallas_County                    41.0
# Davidson_County                  38.0
# Denver_County                    31.0
# Fulton_County                    42.0
# Hennepin_County                  25.0
# Jackson_County                   33.0
# King_County                      44.0
# Los_Angeles_County               56.0
# Maricopa_County                  55.0
# Marion_County                    29.0
# Mecklenburg_County               41.0
# Miami_Dade_County                71.0
# New_York_County                  32.0
# Philadelphia_County              32.0
# San_Francisco_County             56.0
# Suffolk_County                   27.0
# Wayne_County                     25.0

# %%
finalCityDf.to_csv('2015_Weather_Summary.csv', index=True, header=True)
