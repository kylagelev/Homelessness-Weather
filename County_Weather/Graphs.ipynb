# %%
import pandas as pd
import scipy.stats as sts
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
csv2014='2014_All_Temps.csv'
csv2015='2015_All_Temps.csv'

# %%
weather2014Df=pd.read_csv(csv2014)
weather2014Df
# Out:
#              County_Name                 Date  Hourly_Dry_Bulb_Temperature
# 0      Bernalillo_County  2014-01-01T00:15:00                         22.0
# 1      Bernalillo_County  2014-01-01T00:35:00                         23.0
# 2      Bernalillo_County  2014-01-01T00:55:00                         21.0
# 3      Bernalillo_County  2014-01-01T01:15:00                         22.0
# 4      Bernalillo_County  2014-01-01T01:35:00                         21.0
# ...                  ...                  ...                          ...
# 22862       Wayne_County  2014-01-31T20:53:00                         28.0
# 22863       Wayne_County  2014-01-31T21:53:00                         27.0
# 22864       Wayne_County  2014-01-31T22:00:00                         27.0
# 22865       Wayne_County  2014-01-31T22:53:00                         28.0
# 22866       Wayne_County  2014-01-31T23:53:00                         28.0
#
# [22867 rows x 3 columns]

# %%
meanTemps=weather2014Df['Hourly_Dry_Bulb_Temperature']
plt.hist(meanTemps)
# Out:
# <img src="data:image/png;base64,..." width="575.5555708025713">
# (array([ 201.,  619., 1463., 2899., 4324., 4304., 4023., 2340., 2251.,
#          443.]),
#  array([-22. , -11.5,  -1. ,   9.5,  20. ,  30.5,  41. ,  51.5,  62. ,
#          72.5,  83. ]),
#  <BarContainer object of 10 artists>)
