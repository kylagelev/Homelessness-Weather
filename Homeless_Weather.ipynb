# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import linregress

# %%
#homelessness dataframe creation
file_to_load = "Homelessness_Count_USA.csv"
homelessness_data = pd.read_csv(file_to_load)
homelessness_df = pd.DataFrame(homelessness_data)

#reset index to CoC Name
county_homelessness_df = homelessness_df.set_index('CoC Name')

#list of counties for looking through homeless data with
counties = ["Los Angeles City & County CoC", 
            "San Francisco CoC", 
            "Las Vegas/Clark County CoC",
            "Metropolitan Denver Homeless Initiative", 
            "Kansas City/Independence/Lee's Summit/Jackson County CoC", 
            "Cook County CoC", 
            "Fulton County Continuum of Care", 
            "Miami/Dade County CoC", 
            "Philadelphia CoC", 
            "Phoenix/Mesa/Maricopa County Regional CoC",
            "Boston CoC", 
            "Detroit CoC", 
            "Indianapolis CoC", 
            "Seattle/King County CoC", 
            "Dallas City & County/Irving CoC", 
            "Nashville/Davidson County CoC", 
            "Albuquerque CoC", 
            "Charlotte/Mecklenberg CoC", 
            "New York City CoC", 
            "Minneapolis/Hennepin County CoC"]

county_homelessness_df
# Out:
#                       CoC Number                    Year  \
# CoC Name
# Anchorage CoC             AK-500  01/01/2014 12:00:00 AM
# Anchorage CoC             AK-500  01/01/2014 12:00:00 AM
# Anchorage CoC             AK-500  01/01/2014 12:00:00 AM
# Anchorage CoC             AK-500  01/01/2014 12:00:00 AM
# Anchorage CoC             AK-500  01/01/2014 12:00:00 AM
# ...                          ...                     ...
# Wyoming Statewide CoC     WY-500  01/01/2015 12:00:00 AM
# Wyoming Statewide CoC     WY-500  01/01/2015 12:00:00 AM
# Wyoming Statewide CoC     WY-500  01/01/2015 12:00:00 AM
# Wyoming Statewide CoC     WY-500  01/01/2015 12:00:00 AM
# Wyoming Statewide CoC     WY-500  01/01/2015 12:00:00 AM
#
#                                               Attribute Name  Value  \
# CoC Name
# Anchorage CoC                           Chronically Homeless    101
# Anchorage CoC          Sheltered Homeless People in Families    282
# Anchorage CoC                           Homeless Individuals    736
# Anchorage CoC                    Homeless People in Families    287
# Anchorage CoC               Unsheltered Homeless Individuals     48
# ...                                                      ...    ...
# Wyoming Statewide CoC            Homeless People in Families    298
# Wyoming Statewide CoC            Sheltered Homeless Veterans     83
# Wyoming Statewide CoC              Parenting Youth Age 18-24     12
# Wyoming Statewide CoC             Parenting Youth (Under 25)     12
# Wyoming Statewide CoC   Unsheltered Parenting Youth Under 18      0
#
#                        Year - Text
# CoC Name
# Anchorage CoC                 2014
# Anchorage CoC                 2014
# Anchorage CoC                 2014
# Anchorage CoC                 2014
# Anchorage CoC                 2014
# ...                            ...
# Wyoming Statewide CoC         2015
# Wyoming Statewide CoC         2015
# Wyoming Statewide CoC         2015
# Wyoming Statewide CoC         2015
# Wyoming Statewide CoC         2015
#
# [25515 rows x 5 columns]
